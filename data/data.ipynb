# %%
#Used Jupyter notebooks on Anaconda
#used PANDAS, Seaborn , NUMPY, and MatPlotlib 
#Extras dones are Data visualization Bar Plot and Scatter Plot
#Extras done is Used multiple aspects of a single data source in your analysis

# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#read csv file 
df = pd.read_csv('airlines.csv')

# %%
#mean/average of flights on time 
flight_avg = df['Statistics.Flights.On Time'].mean()
print(flight_avg)

#average amount of flights on time are about 9254 flights
# Out:
# 9254.420825771325

# %%
#average amount of flights on time are about 9254 flights

# %%
#finding the median of Statistics.# of Delays.Weather

weatherdelay = df['Statistics.# of Delays.Weather'].median()
print(weatherdelay)

#median of weather delays is 58
# Out:
# 58.0

# %%
#Data visualization of boxplot using seaborn 

sns.set_theme(style = 'whitegrid')
ax = sns.barplot(x = 'Time.Month Name', y = 'Statistics.# of Delays.Weather', data = df)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
#shows the most amount of delays due to weather was in June

# %%
#shows/finds correlation between columns in dataset 
df.corr()
# Out:
#                                                     Time.Month  Time.Year  \
# Time.Month                                            1.000000  -0.075977
# Time.Year                                            -0.075977   1.000000
# Statistics.# of Delays.Carrier                       -0.008749  -0.067204
# Statistics.# of Delays.Late Aircraft                 -0.021178   0.000373
# Statistics.# of Delays.National Aviation System      -0.010177  -0.195279
# Statistics.# of Delays.Security                       0.044398  -0.315334
# Statistics.# of Delays.Weather                       -0.063141  -0.191346
# Statistics.Carriers.Total                             0.009466  -0.483083
# Statistics.Flights.Cancelled                         -0.132985  -0.046951
# Statistics.Flights.Delayed                           -0.016750  -0.127542
# Statistics.Flights.Diverted                          -0.009689  -0.005181
# Statistics.Flights.On Time                            0.024357  -0.052625
# Statistics.Flights.Total                              0.009119  -0.074740
# Statistics.Minutes Delayed.Carrier                   -0.019420   0.028561
# Statistics.Minutes Delayed.Late Aircraft             -0.027362   0.026476
# Statistics.Minutes Delayed.National Aviation Sy...   -0.008659  -0.150661
# Statistics.Minutes Delayed.Security                   0.043901  -0.249772
# Statistics.Minutes Delayed.Total                     -0.021451  -0.069273
# Statistics.Minutes Delayed.Weather                   -0.065504  -0.134033
#
#                                                     Statistics.# of Delays.Carrier  \
# Time.Month                                                               -0.008749
# Time.Year                                                                -0.067204
# Statistics.# of Delays.Carrier                                            1.000000
# Statistics.# of Delays.Late Aircraft                                      0.872725
# Statistics.# of Delays.National Aviation System                           0.648211
# Statistics.# of Delays.Security                                           0.407397
# Statistics.# of Delays.Weather                                            0.729619
# Statistics.Carriers.Total                                                 0.333489
# Statistics.Flights.Cancelled                                              0.518305
# Statistics.Flights.Delayed                                                0.861985
# Statistics.Flights.Diverted                                               0.440189
# Statistics.Flights.On Time                                                0.758744
# Statistics.Flights.Total                                                  0.829259
# Statistics.Minutes Delayed.Carrier                                        0.952155
# Statistics.Minutes Delayed.Late Aircraft                                  0.836543
# Statistics.Minutes Delayed.National Aviation Sy...                        0.532933
# Statistics.Minutes Delayed.Security                                       0.380787
# Statistics.Minutes Delayed.Total                                          0.798300
# Statistics.Minutes Delayed.Weather                                        0.708586
#
#                                                     Statistics.# of Delays.Late Aircraft  \
# Time.Month                                                                     -0.021178
# Time.Year                                                                       0.000373
# Statistics.# of Delays.Carrier                                                  0.872725
# Statistics.# of Delays.Late Aircraft                                            1.000000
# Statistics.# of Delays.National Aviation System                                 0.703330
# Statistics.# of Delays.Security                                                 0.312898
# Statistics.# of Delays.Weather                                                  0.684675
# Statistics.Carriers.Total                                                       0.268856
# Statistics.Flights.Cancelled                                                    0.608284
# Statistics.Flights.Delayed                                                      0.906646
# Statistics.Flights.Diverted                                                     0.541561
# Statistics.Flights.On Time                                                      0.741917
# Statistics.Flights.Total                                                        0.831632
# Statistics.Minutes Delayed.Carrier                                              0.894121
# Statistics.Minutes Delayed.Late Aircraft                                        0.979729
# Statistics.Minutes Delayed.National Aviation Sy...                              0.626905
# Statistics.Minutes Delayed.Security                                             0.297629
# Statistics.Minutes Delayed.Total                                                0.881326
# Statistics.Minutes Delayed.Weather                                              0.697966
#
#                                                     Statistics.# of Delays.National Aviation System  \
# Time.Month                                                                                -0.010177
# Time.Year                                                                                 -0.195279
# Statistics.# of Delays.Carrier                                                             0.648211
# Statistics.# of Delays.Late Aircraft                                                       0.703330
# Statistics.# of Delays.National Aviation System                                            1.000000
# Statistics.# of Delays.Security                                                            0.216732
# Statistics.# of Delays.Weather                                                             0.731453
# Statistics.Carriers.Total                                                                  0.263649
# Statistics.Flights.Cancelled                                                               0.655539
# Statistics.Flights.Delayed                                                                 0.927546
# Statistics.Flights.Diverted                                                                0.485182
# Statistics.Flights.On Time                                                                 0.590919
# Statistics.Flights.Total                                                                   0.721083
# Statistics.Minutes Delayed.Carrier                                                         0.691461
# Statistics.Minutes Delayed.Late Aircraft                                                   0.730317
# Statistics.Minutes Delayed.National Aviation Sy...                                         0.956954
# Statistics.Minutes Delayed.Security                                                        0.243707
# Statistics.Minutes Delayed.Total                                                           0.920091
# Statistics.Minutes Delayed.Weather                                                         0.698585
#
#                                                     Statistics.# of Delays.Security  \
# Time.Month                                                                 0.044398
# Time.Year                                                                 -0.315334
# Statistics.# of Delays.Carrier                                             0.407397
# Statistics.# of Delays.Late Aircraft                                       0.312898
# Statistics.# of Delays.National Aviation System                            0.216732
# Statistics.# of Delays.Security                                            1.000000
# Statistics.# of Delays.Weather                                             0.278034
# Statistics.Carriers.Total                                                  0.235272
# Statistics.Flights.Cancelled                                               0.117530
# Statistics.Flights.Delayed                                                 0.313698
# Statistics.Flights.Diverted                                                0.132249
# Statistics.Flights.On Time                                                 0.258856
# Statistics.Flights.Total                                                   0.285214
# Statistics.Minutes Delayed.Carrier                                         0.297827
# Statistics.Minutes Delayed.Late Aircraft                                   0.263751
# Statistics.Minutes Delayed.National Aviation Sy...                         0.148077
# Statistics.Minutes Delayed.Security                                        0.868281
# Statistics.Minutes Delayed.Total                                           0.244291
# Statistics.Minutes Delayed.Weather                                         0.249887
#
#                                                     Statistics.# of Delays.Weather  \
# Time.Month                                                               -0.063141
# Time.Year                                                                -0.191346
# Statistics.# of Delays.Carrier                                            0.729619
# Statistics.# of Delays.Late Aircraft                                      0.684675
# Statistics.# of Delays.National Aviation System                           0.731453
# Statistics.# of Delays.Security                                           0.278034
# Statistics.# of Delays.Weather                                            1.000000
# Statistics.Carriers.Total                                                 0.234537
# Statistics.Flights.Cancelled                                              0.586373
# Statistics.Flights.Delayed                                                0.804410
# Statistics.Flights.Diverted                                               0.563340
# Statistics.Flights.On Time                                                0.556228
# Statistics.Flights.Total                                                  0.660898
# Statistics.Minutes Delayed.Carrier                                        0.755613
# Statistics.Minutes Delayed.Late Aircraft                                  0.697096
# Statistics.Minutes Delayed.National Aviation Sy...                        0.659647
# Statistics.Minutes Delayed.Security                                       0.280510
# Statistics.Minutes Delayed.Total                                          0.787211
# Statistics.Minutes Delayed.Weather                                        0.962323
#
#                                                     Statistics.Carriers.Total  \
# Time.Month                                                           0.009466
# Time.Year                                                           -0.483083
# Statistics.# of Delays.Carrier                                       0.333489
# Statistics.# of Delays.Late Aircraft                                 0.268856
# Statistics.# of Delays.National Aviation System                      0.263649
# Statistics.# of Delays.Security                                      0.235272
# Statistics.# of Delays.Weather                                       0.234537
# Statistics.Carriers.Total                                            1.000000
# Statistics.Flights.Cancelled                                         0.160970
# Statistics.Flights.Delayed                                           0.305701
# Statistics.Flights.Diverted                                          0.074464
# Statistics.Flights.On Time                                           0.280551
# Statistics.Flights.Total                                             0.301617
# Statistics.Minutes Delayed.Carrier                                   0.250009
# Statistics.Minutes Delayed.Late Aircraft                             0.223946
# Statistics.Minutes Delayed.National Aviation Sy...                   0.198423
# Statistics.Minutes Delayed.Security                                  0.203467
# Statistics.Minutes Delayed.Total                                     0.241707
# Statistics.Minutes Delayed.Weather                                   0.200550
#
#                                                     Statistics.Flights.Cancelled  \
# Time.Month                                                             -0.132985
# Time.Year                                                              -0.046951
# Statistics.# of Delays.Carrier                                          0.518305
# Statistics.# of Delays.Late Aircraft                                    0.608284
# Statistics.# of Delays.National Aviation System                         0.655539
# Statistics.# of Delays.Security                                         0.117530
# Statistics.# of Delays.Weather                                          0.586373
# Statistics.Carriers.Total                                               0.160970
# Statistics.Flights.Cancelled                                            1.000000
# Statistics.Flights.Delayed                                              0.678981
# Statistics.Flights.Diverted                                             0.428933
# Statistics.Flights.On Time                                              0.413247
# Statistics.Flights.Total                                                0.535110
# Statistics.Minutes Delayed.Carrier                                      0.591412
# Statistics.Minutes Delayed.Late Aircraft                                0.656723
# Statistics.Minutes Delayed.National Aviation Sy...                      0.675313
# Statistics.Minutes Delayed.Security                                     0.138741
# Statistics.Minutes Delayed.Total                                        0.726973
# Statistics.Minutes Delayed.Weather                                      0.626871
#
#                                                     Statistics.Flights.Delayed  \
# Time.Month                                                           -0.016750
# Time.Year                                                            -0.127542
# Statistics.# of Delays.Carrier                                        0.861985
# Statistics.# of Delays.Late Aircraft                                  0.906646
# Statistics.# of Delays.National Aviation System                       0.927546
# Statistics.# of Delays.Security                                       0.313698
# Statistics.# of Delays.Weather                                        0.804410
# Statistics.Carriers.Total                                             0.305701
# Statistics.Flights.Cancelled                                          0.678981
# Statistics.Flights.Delayed                                            1.000000
# Statistics.Flights.Diverted                                           0.549239
# Statistics.Flights.On Time                                            0.733519
# Statistics.Flights.Total                                              0.851394
# Statistics.Minutes Delayed.Carrier                                    0.883851
# Statistics.Minutes Delayed.Late Aircraft                              0.907936
# Statistics.Minutes Delayed.National Aviation Sy...                    0.853660
# Statistics.Minutes Delayed.Security                                   0.317777
# Statistics.Minutes Delayed.Total                                      0.974404
# Statistics.Minutes Delayed.Weather                                    0.785264
#
#                                                     Statistics.Flights.Diverted  \
# Time.Month                                                            -0.009689
# Time.Year                                                             -0.005181
# Statistics.# of Delays.Carrier                                         0.440189
# Statistics.# of Delays.Late Aircraft                                   0.541561
# Statistics.# of Delays.National Aviation System                        0.485182
# Statistics.# of Delays.Security                                        0.132249
# Statistics.# of Delays.Weather                                         0.563340
# Statistics.Carriers.Total                                              0.074464
# Statistics.Flights.Cancelled                                           0.428933
# Statistics.Flights.Delayed                                             0.549239
# Statistics.Flights.Diverted                                            1.000000
# Statistics.Flights.On Time                                             0.426534
# Statistics.Flights.Total                                               0.492078
# Statistics.Minutes Delayed.Carrier                                     0.536772
# Statistics.Minutes Delayed.Late Aircraft                               0.583749
# Statistics.Minutes Delayed.National Aviation Sy...                     0.494755
# Statistics.Minutes Delayed.Security                                    0.138240
# Statistics.Minutes Delayed.Total                                       0.598963
# Statistics.Minutes Delayed.Weather                                     0.622907
#
#                                                     Statistics.Flights.On Time  \
# Time.Month                                                            0.024357
# Time.Year                                                            -0.052625
# Statistics.# of Delays.Carrier                                        0.758744
# Statistics.# of Delays.Late Aircraft                                  0.741917
# Statistics.# of Delays.National Aviation System                       0.590919
# Statistics.# of Delays.Security                                       0.258856
# Statistics.# of Delays.Weather                                        0.556228
# Statistics.Carriers.Total                                             0.280551
# Statistics.Flights.Cancelled                                          0.413247
# Statistics.Flights.Delayed                                            0.733519
# Statistics.Flights.Diverted                                           0.426534
# Statistics.Flights.On Time                                            1.000000
# Statistics.Flights.Total                                              0.980386
# Statistics.Minutes Delayed.Carrier                                    0.793701
# Statistics.Minutes Delayed.Late Aircraft                              0.679285
# Statistics.Minutes Delayed.National Aviation Sy...                    0.459501
# Statistics.Minutes Delayed.Security                                   0.277683
# Statistics.Minutes Delayed.Total                                      0.663572
# Statistics.Minutes Delayed.Weather                                    0.531387
#
#                                                     Statistics.Flights.Total  \
# Time.Month                                                          0.009119
# Time.Year                                                          -0.074740
# Statistics.# of Delays.Carrier                                      0.829259
# Statistics.# of Delays.Late Aircraft                                0.831632
# Statistics.# of Delays.National Aviation System                     0.721083
# Statistics.# of Delays.Security                                     0.285214
# Statistics.# of Delays.Weather                                      0.660898
# Statistics.Carriers.Total                                           0.301617
# Statistics.Flights.Cancelled                                        0.535110
# Statistics.Flights.Delayed                                          0.851394
# Statistics.Flights.Diverted                                         0.492078
# Statistics.Flights.On Time                                          0.980386
# Statistics.Flights.Total                                            1.000000
# Statistics.Minutes Delayed.Carrier                                  0.865491
# Statistics.Minutes Delayed.Late Aircraft                            0.785499
# Statistics.Minutes Delayed.National Aviation Sy...                  0.601323
# Statistics.Minutes Delayed.Security                                 0.301800
# Statistics.Minutes Delayed.Total                                    0.792889
# Statistics.Minutes Delayed.Weather                                  0.638822
#
#                                                     Statistics.Minutes Delayed.Carrier  \
# Time.Month                                                                   -0.019420
# Time.Year                                                                     0.028561
# Statistics.# of Delays.Carrier                                                0.952155
# Statistics.# of Delays.Late Aircraft                                          0.894121
# Statistics.# of Delays.National Aviation System                               0.691461
# Statistics.# of Delays.Security                                               0.297827
# Statistics.# of Delays.Weather                                                0.755613
# Statistics.Carriers.Total                                                     0.250009
# Statistics.Flights.Cancelled                                                  0.591412
# Statistics.Flights.Delayed                                                    0.883851
# Statistics.Flights.Diverted                                                   0.536772
# Statistics.Flights.On Time                                                    0.793701
# Statistics.Flights.Total                                                      0.865491
# Statistics.Minutes Delayed.Carrier                                            1.000000
# Statistics.Minutes Delayed.Late Aircraft                                      0.884543
# Statistics.Minutes Delayed.National Aviation Sy...                            0.596586
# Statistics.Minutes Delayed.Security                                           0.304070
# Statistics.Minutes Delayed.Total                                              0.859861
# Statistics.Minutes Delayed.Weather                                            0.761585
#
#                                                     Statistics.Minutes Delayed.Late Aircraft  \
# Time.Month                                                                         -0.027362
# Time.Year                                                                           0.026476
# Statistics.# of Delays.Carrier                                                      0.836543
# Statistics.# of Delays.Late Aircraft                                                0.979729
# Statistics.# of Delays.National Aviation System                                     0.730317
# Statistics.# of Delays.Security                                                     0.263751
# Statistics.# of Delays.Weather                                                      0.697096
# Statistics.Carriers.Total                                                           0.223946
# Statistics.Flights.Cancelled                                                        0.656723
# Statistics.Flights.Delayed                                                          0.907936
# Statistics.Flights.Diverted                                                         0.583749
# Statistics.Flights.On Time                                                          0.679285
# Statistics.Flights.Total                                                            0.785499
# Statistics.Minutes Delayed.Carrier                                                  0.884543
# Statistics.Minutes Delayed.Late Aircraft                                            1.000000
# Statistics.Minutes Delayed.National Aviation Sy...                                  0.690135
# Statistics.Minutes Delayed.Security                                                 0.262286
# Statistics.Minutes Delayed.Total                                                    0.919721
# Statistics.Minutes Delayed.Weather                                                  0.727009
#
#                                                     Statistics.Minutes Delayed.National Aviation System  \
# Time.Month                                                                                  -0.008659
# Time.Year                                                                                   -0.150661
# Statistics.# of Delays.Carrier                                                               0.532933
# Statistics.# of Delays.Late Aircraft                                                         0.626905
# Statistics.# of Delays.National Aviation System                                              0.956954
# Statistics.# of Delays.Security                                                              0.148077
# Statistics.# of Delays.Weather                                                               0.659647
# Statistics.Carriers.Total                                                                    0.198423
# Statistics.Flights.Cancelled                                                                 0.675313
# Statistics.Flights.Delayed                                                                   0.853660
# Statistics.Flights.Diverted                                                                  0.494755
# Statistics.Flights.On Time                                                                   0.459501
# Statistics.Flights.Total                                                                     0.601323
# Statistics.Minutes Delayed.Carrier                                                           0.596586
# Statistics.Minutes Delayed.Late Aircraft                                                     0.690135
# Statistics.Minutes Delayed.National Aviation Sy...                                           1.000000
# Statistics.Minutes Delayed.Security                                                          0.184170
# Statistics.Minutes Delayed.Total                                                             0.905290
# Statistics.Minutes Delayed.Weather                                                           0.654201
#
#                                                     Statistics.Minutes Delayed.Security  \
# Time.Month                                                                     0.043901
# Time.Year                                                                     -0.249772
# Statistics.# of Delays.Carrier                                                 0.380787
# Statistics.# of Delays.Late Aircraft                                           0.297629
# Statistics.# of Delays.National Aviation System                                0.243707
# Statistics.# of Delays.Security                                                0.868281
# Statistics.# of Delays.Weather                                                 0.280510
# Statistics.Carriers.Total                                                      0.203467
# Statistics.Flights.Cancelled                                                   0.138741
# Statistics.Flights.Delayed                                                     0.317777
# Statistics.Flights.Diverted                                                    0.138240
# Statistics.Flights.On Time                                                     0.277683
# Statistics.Flights.Total                                                       0.301800
# Statistics.Minutes Delayed.Carrier                                             0.304070
# Statistics.Minutes Delayed.Late Aircraft                                       0.262286
# Statistics.Minutes Delayed.National Aviation Sy...                             0.184170
# Statistics.Minutes Delayed.Security                                            1.000000
# Statistics.Minutes Delayed.Total                                               0.263676
# Statistics.Minutes Delayed.Weather                                             0.249901
#
#                                                     Statistics.Minutes Delayed.Total  \
# Time.Month                                                                 -0.021451
# Time.Year                                                                  -0.069273
# Statistics.# of Delays.Carrier                                              0.798300
# Statistics.# of Delays.Late Aircraft                                        0.881326
# Statistics.# of Delays.National Aviation System                             0.920091
# Statistics.# of Delays.Security                                             0.244291
# Statistics.# of Delays.Weather                                              0.787211
# Statistics.Carriers.Total                                                   0.241707
# Statistics.Flights.Cancelled                                                0.726973
# Statistics.Flights.Delayed                                                  0.974404
# Statistics.Flights.Diverted                                                 0.598963
# Statistics.Flights.On Time                                                  0.663572
# Statistics.Flights.Total                                                    0.792889
# Statistics.Minutes Delayed.Carrier                                          0.859861
# Statistics.Minutes Delayed.Late Aircraft                                    0.919721
# Statistics.Minutes Delayed.National Aviation Sy...                          0.905290
# Statistics.Minutes Delayed.Security                                         0.263676
# Statistics.Minutes Delayed.Total                                            1.000000
# Statistics.Minutes Delayed.Weather                                          0.797974
#
#                                                     Statistics.Minutes Delayed.Weather
# Time.Month                                                                   -0.065504
# Time.Year                                                                    -0.134033
# Statistics.# of Delays.Carrier                                                0.708586
# Statistics.# of Delays.Late Aircraft                                          0.697966
# Statistics.# of Delays.National Aviation System                               0.698585
# Statistics.# of Delays.Security                                               0.249887
# Statistics.# of Delays.Weather                                                0.962323
# Statistics.Carriers.Total                                                     0.200550
# Statistics.Flights.Cancelled                                                  0.626871
# Statistics.Flights.Delayed                                                    0.785264
# Statistics.Flights.Diverted                                                   0.622907
# Statistics.Flights.On Time                                                    0.531387
# Statistics.Flights.Total                                                      0.638822
# Statistics.Minutes Delayed.Carrier                                            0.761585
# Statistics.Minutes Delayed.Late Aircraft                                      0.727009
# Statistics.Minutes Delayed.National Aviation Sy...                            0.654201
# Statistics.Minutes Delayed.Security                                           0.249901
# Statistics.Minutes Delayed.Total                                              0.797974
# Statistics.Minutes Delayed.Weather                                            1.000000

# %%
 #Shows poor correlation between the month and the amount of flights cancelled
#chart above says correlation coefficient between month and flights canceled is -0.132985

# %%
data = df
month = data['Time.Month']#sets physical health to the physical health column 
flightcancelled = data['Statistics.Flights.Cancelled'] #sets BMI to BMI column 
plt.scatter(month,flightcancelled, edgecolor = 'black', alpha =.3)
plt.title('Month and Flights Cancelled')
plt.xlabel('Month')
plt.ylabel('FlightCancelled')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
